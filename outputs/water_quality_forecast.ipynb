# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.plot(range(1, len(predictions)+1), predictions[:,0], marker='o', color='blue')
plt.title("Water Quality Forecast")
plt.xlabel("Month")
plt.ylabel("Predicted Value")
plt.grid(True)

# Save figure in outputs folder
plt.savefig("outputs/water_quality_forecast.png")

# Show in Streamlit
st.pyplot(plt)
st.success("Plot saved to outputs/water_quality_forecast.png ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(8,4))
# ----> 3 plt.plot(range(1, len(predictions)+1), predictions[:,0], marker='o', color='blue')
#       4 plt.title("Water Quality Forecast")
#       5 plt.xlabel("Month")
#
# NameError: name 'predictions' is not defined
